# %%
import os
import os.path

IMAGE_DIR='images'
FACE_DIR='faces'

if not os.path.exists(FACE_DIR):
    os.mkdir(FACE_DIR)

# %%
import PIL
import numpy
import face_recognition

MAXDIM = 2048

def detect_faces(filename):
    filepath = os.path.join(IMAGE_DIR, filename)
    try:
        im = PIL.Image.open(filepath)
        im = im.convert('RGB')
    except:
        return None
    scale = 0.0
    if im.height > MAXDIM or im.width > MAXDIM:
        origheight = im.height
        im.thumbnail((MAXDIM,MAXDIM))
        scale = origheight / im.height
    image = numpy.array(im)
    face_locations = face_recognition.face_locations(image, model='hog')
    return (filename, image, face_locations, scale)

def get_encodings(filename, image, face_locations):
    if len(face_locations) == 0:
        return [], []
    face_encodings = face_recognition.face_encodings(image, face_locations)
    return face_encodings

# %%
# %%time
import time

all_filenames = [fn for fn in os.listdir(IMAGE_DIR)
                 if not os.path.exists(os.path.join(FACE_DIR, fn + '.ndjson'))]

BATCHSIZE=1024

def process_batch(batch_filenames):
    from multiprocessing import Pool
    import json
    with Pool(8) as pool:
        image_faces = filter(None, pool.map(detect_faces, batch_filenames))

    faces = []
    for filename, image, face_locations, scale in image_faces:    
        face_encodings = get_encodings(filename, image, face_locations)
        if scale:
            face_locations = [tuple([int(scale * loc) for loc in location]) for location in face_locations]
        with open(os.path.join(FACE_DIR, filename + '.ndjson'), 'w') as facefile:
            for loc, enc in zip(face_locations, face_encodings):
                print(json.dumps({'id': filename, 'location': loc, 'encoding': list(enc)}), file=facefile)

for batch in range(0, len(all_filenames), BATCHSIZE):
    starttime = time.time()
    batch_filenames = all_filenames[batch:batch+BATCHSIZE]
    print("Starting batch of {} images from index {}".format(len(batch_filenames), batch))
    process_batch(batch_filenames)
    print("Batch completed in {:.02f} seconds".format(time.time() - starttime))
# Out:
# Starting batch of 1024 images from index 0
# Batch completed in 190.89 seconds
# Starting batch of 1024 images from index 1024
# Batch completed in 149.72 seconds
# Starting batch of 1024 images from index 2048
# Batch completed in 165.41 seconds
# Starting batch of 1024 images from index 3072
# Batch completed in 150.31 seconds
# Starting batch of 1024 images from index 4096
# Batch completed in 156.80 seconds
# Starting batch of 1024 images from index 5120
# Batch completed in 152.18 seconds
# Starting batch of 1024 images from index 6144
# Batch completed in 162.08 seconds
# Starting batch of 1024 images from index 7168
# Batch completed in 149.72 seconds
# Starting batch of 1024 images from index 8192
# Batch completed in 154.49 seconds
# Starting batch of 1024 images from index 9216
# Batch completed in 138.46 seconds
# Starting batch of 1024 images from index 10240
# Batch completed in 158.30 seconds
# Starting batch of 1024 images from index 11264
# Batch completed in 151.25 seconds
# Starting batch of 1024 images from index 12288
# Batch completed in 161.97 seconds
# Starting batch of 1024 images from index 13312
# Batch completed in 163.68 seconds
# Starting batch of 1024 images from index 14336
# Batch completed in 148.50 seconds
# Starting batch of 1024 images from index 15360
# Batch completed in 152.79 seconds
# Starting batch of 1024 images from index 16384
# Batch completed in 152.33 seconds
# Starting batch of 1024 images from index 17408
# Batch completed in 151.98 seconds
# Starting batch of 1024 images from index 18432
# Batch completed in 147.53 seconds
# Starting batch of 1024 images from index 19456
# Batch completed in 159.09 seconds
# Starting batch of 1024 images from index 20480
# Batch completed in 153.20 seconds
# Starting batch of 1024 images from index 21504
# Batch completed in 151.35 seconds
# Starting batch of 1024 images from index 22528
# Batch completed in 150.68 seconds
# Starting batch of 1024 images from index 23552
# Batch completed in 168.74 seconds
# Starting batch of 1024 images from index 24576
# Batch completed in 160.67 seconds
# Starting batch of 1024 images from index 25600
# Batch completed in 145.35 seconds
# Starting batch of 1024 images from index 26624
# Batch completed in 171.47 seconds
# Starting batch of 1024 images from index 27648
# Batch completed in 159.08 seconds
# Starting batch of 1024 images from index 28672
# Batch completed in 165.71 seconds
# Starting batch of 1024 images from index 29696
# Batch completed in 155.75 seconds
# Starting batch of 1024 images from index 30720
# Batch completed in 166.89 seconds
# Starting batch of 1024 images from index 31744
# Batch completed in 157.46 seconds
# Starting batch of 1024 images from index 32768
# Batch completed in 173.23 seconds
# Starting batch of 1024 images from index 33792
# Batch completed in 147.69 seconds
# Starting batch of 1024 images from index 34816
# Batch completed in 164.44 seconds
# Starting batch of 1024 images from index 35840
# Batch completed in 147.51 seconds
# Starting batch of 1024 images from index 36864
# Batch completed in 168.08 seconds
# Starting batch of 1024 images from index 37888
# Batch completed in 158.25 seconds
# Starting batch of 1024 images from index 38912
# Batch completed in 145.64 seconds
# Starting batch of 1024 images from index 39936
# Batch completed in 151.30 seconds
# Starting batch of 1024 images from index 40960
# Batch completed in 166.62 seconds
# Starting batch of 1024 images from index 41984
# Batch completed in 148.91 seconds
# Starting batch of 1024 images from index 43008
# Batch completed in 164.06 seconds
# Starting batch of 1024 images from index 44032
# Batch completed in 158.77 seconds
# Starting batch of 1024 images from index 45056
# Batch completed in 154.41 seconds
# Starting batch of 1024 images from index 46080
# Batch completed in 153.52 seconds
# Starting batch of 1024 images from index 47104
# Batch completed in 157.71 seconds
# Starting batch of 1024 images from index 48128
# Batch completed in 157.49 seconds
# Starting batch of 1024 images from index 49152
# Batch completed in 175.49 seconds
# Starting batch of 1024 images from index 50176
# Batch completed in 177.95 seconds
# Starting batch of 1024 images from index 51200
# Batch completed in 158.48 seconds
# Starting batch of 1024 images from index 52224
# Batch completed in 156.04 seconds
# Starting batch of 1024 images from index 53248
# Batch completed in 166.36 seconds
# Starting batch of 1024 images from index 54272
# Batch completed in 145.26 seconds
# Starting batch of 1024 images from index 55296
# Batch completed in 155.15 seconds
# Starting batch of 1024 images from index 56320
# Batch completed in 158.91 seconds
# Starting batch of 1024 images from index 57344
# Batch completed in 150.09 seconds
# Starting batch of 1024 images from index 58368
# Batch completed in 166.13 seconds
# Starting batch of 1024 images from index 59392
# Batch completed in 154.12 seconds
# Starting batch of 1024 images from index 60416
# /home/ozone/proj/finnanaama/venv2/lib/python3.6/site-packages/PIL/TiffImagePlugin.py:785: UserWarning: Corrupt EXIF data.  Expecting to read 4 bytes but only got 0.
#   warnings.warn(str(msg))
# Batch completed in 168.07 seconds
# Starting batch of 1024 images from index 61440
# Batch completed in 168.90 seconds
# Starting batch of 1024 images from index 62464
# Batch completed in 150.24 seconds
# Starting batch of 1024 images from index 63488
# Batch completed in 168.11 seconds
# Starting batch of 1024 images from index 64512
# Batch completed in 163.75 seconds
# Starting batch of 1024 images from index 65536
# Batch completed in 164.70 seconds
# Starting batch of 1024 images from index 66560
# Batch completed in 156.32 seconds
# Starting batch of 1024 images from index 67584
# Batch completed in 165.28 seconds
# Starting batch of 1024 images from index 68608
# Batch completed in 144.17 seconds
# Starting batch of 1024 images from index 69632
# Batch completed in 155.73 seconds
# Starting batch of 1024 images from index 70656
# Batch completed in 145.35 seconds
# Starting batch of 1024 images from index 71680
# Batch completed in 177.93 seconds
# Starting batch of 1024 images from index 72704
# Batch completed in 162.33 seconds
# Starting batch of 1024 images from index 73728
# Batch completed in 142.37 seconds
# Starting batch of 1024 images from index 74752
# Batch completed in 155.91 seconds
# Starting batch of 1024 images from index 75776
# Batch completed in 158.89 seconds
# Starting batch of 1024 images from index 76800
# Batch completed in 153.53 seconds
# Starting batch of 1024 images from index 77824
# Batch completed in 165.95 seconds
# Starting batch of 1024 images from index 78848
# Batch completed in 142.40 seconds
# Starting batch of 1024 images from index 79872
# Batch completed in 142.54 seconds
# Starting batch of 1024 images from index 80896
# Batch completed in 160.66 seconds
# Starting batch of 1024 images from index 81920
# Batch completed in 155.21 seconds
# Starting batch of 1024 images from index 82944
# Batch completed in 158.73 seconds
# Starting batch of 1024 images from index 83968
# Batch completed in 157.29 seconds
# Starting batch of 1024 images from index 84992
# Batch completed in 153.31 seconds
# Starting batch of 1024 images from index 86016
# Batch completed in 154.77 seconds
# Starting batch of 1024 images from index 87040
# Batch completed in 159.22 seconds
# Starting batch of 1024 images from index 88064
# Batch completed in 169.03 seconds
# Starting batch of 1024 images from index 89088
# Batch completed in 137.03 seconds
# Starting batch of 1024 images from index 90112
# Batch completed in 158.70 seconds
# Starting batch of 1024 images from index 91136
# Batch completed in 153.54 seconds
# Starting batch of 1024 images from index 92160
# Batch completed in 144.68 seconds
# Starting batch of 1024 images from index 93184
# Batch completed in 168.53 seconds
# Starting batch of 1024 images from index 94208
# Batch completed in 147.60 seconds
# Starting batch of 1024 images from index 95232
# Batch completed in 148.90 seconds
# Starting batch of 1024 images from index 96256
# Batch completed in 172.01 seconds
# Starting batch of 1024 images from index 97280
# Batch completed in 159.80 seconds
# Starting batch of 1024 images from index 98304
# Batch completed in 156.48 seconds
# Starting batch of 1024 images from index 99328
# Batch completed in 153.67 seconds
# Starting batch of 1024 images from index 100352
# Batch completed in 140.36 seconds
# Starting batch of 1024 images from index 101376
# Batch completed in 154.89 seconds
# Starting batch of 1024 images from index 102400
# Batch completed in 160.81 seconds
# Starting batch of 1024 images from index 103424
# Batch completed in 151.46 seconds
# Starting batch of 1024 images from index 104448
# Batch completed in 159.97 seconds
# Starting batch of 1024 images from index 105472
# Batch completed in 166.34 seconds
# Starting batch of 1024 images from index 106496
# Batch completed in 155.47 seconds
# Starting batch of 1024 images from index 107520
# Batch completed in 146.93 seconds
# Starting batch of 1024 images from index 108544
# Batch completed in 154.70 seconds
# Starting batch of 1024 images from index 109568
# Batch completed in 168.94 seconds
# Starting batch of 1024 images from index 110592
# Batch completed in 167.23 seconds
# Starting batch of 1024 images from index 111616
# Batch completed in 147.87 seconds
# Starting batch of 1024 images from index 112640
# Batch completed in 154.39 seconds
# Starting batch of 1024 images from index 113664
# Batch completed in 146.98 seconds
# Starting batch of 1024 images from index 114688
# Batch completed in 170.40 seconds
# Starting batch of 1024 images from index 115712
# Batch completed in 148.48 seconds
# Starting batch of 1024 images from index 116736
# Batch completed in 134.05 seconds
# Starting batch of 1024 images from index 117760
# Batch completed in 152.83 seconds
# Starting batch of 1024 images from index 118784
# Batch completed in 151.53 seconds
# Starting batch of 1024 images from index 119808
# Batch completed in 162.20 seconds
# Starting batch of 1024 images from index 120832
# Batch completed in 166.53 seconds
# Starting batch of 1024 images from index 121856
# Batch completed in 171.31 seconds
# Starting batch of 1024 images from index 122880
# Batch completed in 152.66 seconds
# Starting batch of 1024 images from index 123904
# Batch completed in 158.12 seconds
# Starting batch of 1024 images from index 124928
# Batch completed in 158.60 seconds
# Starting batch of 1024 images from index 125952
# Batch completed in 151.85 seconds
# Starting batch of 1024 images from index 126976
# Batch completed in 154.03 seconds
# Starting batch of 1024 images from index 128000
# Batch completed in 156.91 seconds
# Starting batch of 1024 images from index 129024
# Batch completed in 153.69 seconds
# Starting batch of 1024 images from index 130048
# Batch completed in 160.91 seconds
# Starting batch of 1024 images from index 131072
# Batch completed in 153.81 seconds
# Starting batch of 1024 images from index 132096
# Batch completed in 145.32 seconds
# Starting batch of 1024 images from index 133120
# Batch completed in 152.46 seconds
# Starting batch of 1024 images from index 134144
# Batch completed in 151.39 seconds
# Starting batch of 1024 images from index 135168
# Batch completed in 161.20 seconds
# Starting batch of 1024 images from index 136192
# Batch completed in 176.83 seconds
# Starting batch of 1024 images from index 137216
# Batch completed in 153.97 seconds
# Starting batch of 1024 images from index 138240
# Batch completed in 167.45 seconds
# Starting batch of 1024 images from index 139264
# Batch completed in 161.47 seconds
# Starting batch of 1024 images from index 140288
# Batch completed in 156.31 seconds
# Starting batch of 1024 images from index 141312
# Batch completed in 165.22 seconds
# Starting batch of 1024 images from index 142336
# Batch completed in 165.19 seconds
# Starting batch of 1024 images from index 143360
# Batch completed in 161.26 seconds
# Starting batch of 1024 images from index 144384
# Batch completed in 165.67 seconds
# Starting batch of 1024 images from index 145408
# Batch completed in 165.65 seconds
# Starting batch of 1024 images from index 146432
# Batch completed in 151.82 seconds
# Starting batch of 1024 images from index 147456
# Batch completed in 160.13 seconds
# Starting batch of 1024 images from index 148480
# Batch completed in 158.67 seconds
# Starting batch of 1024 images from index 149504
# Batch completed in 156.75 seconds
# Starting batch of 1024 images from index 150528
# Batch completed in 153.30 seconds
# Starting batch of 1024 images from index 151552
# Batch completed in 148.72 seconds
# Starting batch of 1024 images from index 152576
# Batch completed in 144.75 seconds
# Starting batch of 1024 images from index 153600
# Batch completed in 159.26 seconds
# Starting batch of 1024 images from index 154624
# Batch completed in 152.75 seconds
# Starting batch of 1024 images from index 155648
# Batch completed in 155.46 seconds
# Starting batch of 1024 images from index 156672
# Batch completed in 174.37 seconds
# Starting batch of 1024 images from index 157696
# Batch completed in 165.11 seconds
# Starting batch of 1024 images from index 158720
# Batch completed in 154.67 seconds
# Starting batch of 1024 images from index 159744
# Batch completed in 154.14 seconds
# Starting batch of 1024 images from index 160768
# Batch completed in 142.84 seconds
# Starting batch of 1024 images from index 161792
# Batch completed in 159.97 seconds
# Starting batch of 1024 images from index 162816
# Batch completed in 163.35 seconds
# Starting batch of 1024 images from index 163840
# Batch completed in 154.39 seconds
# Starting batch of 1024 images from index 164864
# Batch completed in 151.96 seconds
# Starting batch of 1024 images from index 165888
# Batch completed in 164.80 seconds
# Starting batch of 1024 images from index 166912
# Batch completed in 160.54 seconds
# Starting batch of 1024 images from index 167936
# Batch completed in 165.63 seconds
# Starting batch of 1024 images from index 168960
# Batch completed in 157.47 seconds
# Starting batch of 1024 images from index 169984
# Batch completed in 157.08 seconds
# Starting batch of 1024 images from index 171008
# Batch completed in 156.53 seconds
# Starting batch of 1024 images from index 172032
# Batch completed in 164.91 seconds
# Starting batch of 1024 images from index 173056
# Batch completed in 166.36 seconds
# Starting batch of 1024 images from index 174080
# Batch completed in 160.63 seconds
# Starting batch of 1024 images from index 175104
# Batch completed in 146.20 seconds
# Starting batch of 1024 images from index 176128
# Batch completed in 141.07 seconds
# Starting batch of 1024 images from index 177152
# Batch completed in 161.83 seconds
# Starting batch of 1024 images from index 178176
# Batch completed in 147.16 seconds
# Starting batch of 1024 images from index 179200
# Batch completed in 153.06 seconds
# Starting batch of 1024 images from index 180224
# Batch completed in 153.79 seconds
# Starting batch of 1024 images from index 181248
# Batch completed in 170.02 seconds
# Starting batch of 1024 images from index 182272
# Batch completed in 153.79 seconds
# Starting batch of 1024 images from index 183296
# Batch completed in 191.01 seconds
# Starting batch of 1024 images from index 184320
# Batch completed in 146.59 seconds
# Starting batch of 1024 images from index 185344
# Batch completed in 164.73 seconds
# Starting batch of 1024 images from index 186368
# Batch completed in 154.23 seconds
# Starting batch of 1024 images from index 187392
# Batch completed in 138.94 seconds
# Starting batch of 1024 images from index 188416
# Batch completed in 165.98 seconds
# Starting batch of 1024 images from index 189440
# Batch completed in 158.35 seconds
# Starting batch of 1024 images from index 190464
# Batch completed in 155.61 seconds
# Starting batch of 1024 images from index 191488
# Batch completed in 164.11 seconds
# Starting batch of 1024 images from index 192512
# Batch completed in 157.40 seconds
# Starting batch of 1024 images from index 193536
# Batch completed in 154.37 seconds
# Starting batch of 1024 images from index 194560
# Batch completed in 137.41 seconds
# Starting batch of 1024 images from index 195584
# Batch completed in 157.20 seconds
# Starting batch of 1024 images from index 196608
# Batch completed in 170.13 seconds
# Starting batch of 1024 images from index 197632
# Batch completed in 157.02 seconds
# Starting batch of 1024 images from index 198656
# Batch completed in 152.24 seconds
# Starting batch of 1024 images from index 199680
# Batch completed in 147.74 seconds
# Starting batch of 1024 images from index 200704
# Batch completed in 156.20 seconds
# Starting batch of 1024 images from index 201728
# Batch completed in 149.18 seconds
# Starting batch of 1024 images from index 202752
# Batch completed in 162.96 seconds
# Starting batch of 1024 images from index 203776
# Batch completed in 161.51 seconds
# Starting batch of 1024 images from index 204800
# Batch completed in 159.75 seconds
# Starting batch of 1024 images from index 205824
# Batch completed in 162.08 seconds
# Starting batch of 1024 images from index 206848
# Batch completed in 165.69 seconds
# Starting batch of 1024 images from index 207872
# Batch completed in 143.73 seconds
# Starting batch of 1024 images from index 208896
# Batch completed in 166.60 seconds
# Starting batch of 1024 images from index 209920
# Batch completed in 168.94 seconds
# Starting batch of 1024 images from index 210944
# Batch completed in 178.57 seconds
# Starting batch of 1024 images from index 211968
# Batch completed in 160.17 seconds
# Starting batch of 1024 images from index 212992
# Batch completed in 147.21 seconds
# Starting batch of 1024 images from index 214016
# Batch completed in 149.89 seconds
# Starting batch of 1024 images from index 215040
# Batch completed in 173.92 seconds
# Starting batch of 1024 images from index 216064
# Batch completed in 153.50 seconds
# Starting batch of 1024 images from index 217088
# Batch completed in 160.29 seconds
# Starting batch of 1024 images from index 218112
# Batch completed in 151.93 seconds
# Starting batch of 1024 images from index 219136
# Batch completed in 153.04 seconds
# Starting batch of 1024 images from index 220160
# Batch completed in 144.82 seconds
# Starting batch of 1024 images from index 221184
# Batch completed in 145.07 seconds
# Starting batch of 1024 images from index 222208
# Batch completed in 156.95 seconds
# Starting batch of 1024 images from index 223232
# Batch completed in 162.44 seconds
# Starting batch of 1024 images from index 224256
# Batch completed in 157.74 seconds
# Starting batch of 1024 images from index 225280
# Batch completed in 150.59 seconds
# Starting batch of 1024 images from index 226304
# Batch completed in 157.29 seconds
# Starting batch of 1024 images from index 227328
# Batch completed in 169.97 seconds
# Starting batch of 1024 images from index 228352
# Batch completed in 145.19 seconds
# Starting batch of 1024 images from index 229376
# Batch completed in 164.07 seconds
# Starting batch of 1024 images from index 230400
# Batch completed in 149.19 seconds
# Starting batch of 1024 images from index 231424
# Batch completed in 150.54 seconds
# Starting batch of 1024 images from index 232448
# Batch completed in 161.04 seconds
# Starting batch of 1024 images from index 233472
# Batch completed in 144.80 seconds
# Starting batch of 1024 images from index 234496
# Batch completed in 156.81 seconds
# Starting batch of 1024 images from index 235520
# Batch completed in 152.20 seconds
# Starting batch of 1024 images from index 236544
# Batch completed in 159.40 seconds
# Starting batch of 1024 images from index 237568
# Batch completed in 162.04 seconds
# Starting batch of 1024 images from index 238592
# Batch completed in 145.50 seconds
# Starting batch of 1024 images from index 239616
# Batch completed in 167.16 seconds
# Starting batch of 1024 images from index 240640
# Batch completed in 149.55 seconds
# Starting batch of 1024 images from index 241664
# Batch completed in 151.82 seconds
# Starting batch of 1024 images from index 242688
# Batch completed in 155.37 seconds
# Starting batch of 1024 images from index 243712
# Batch completed in 161.75 seconds
# Starting batch of 1024 images from index 244736
# Batch completed in 156.62 seconds
# Starting batch of 1024 images from index 245760
# Batch completed in 155.34 seconds
# Starting batch of 1024 images from index 246784
# Batch completed in 150.36 seconds
# Starting batch of 1024 images from index 247808
# Batch completed in 153.31 seconds
# Starting batch of 1024 images from index 248832
# Batch completed in 153.33 seconds
# Starting batch of 1024 images from index 249856
# Batch completed in 160.31 seconds
# Starting batch of 1024 images from index 250880
# Batch completed in 152.83 seconds
# Starting batch of 1024 images from index 251904
# Batch completed in 156.55 seconds
# Starting batch of 1024 images from index 252928
# Batch completed in 162.54 seconds
# Starting batch of 1024 images from index 253952
# Batch completed in 159.28 seconds
# Starting batch of 1024 images from index 254976
# Batch completed in 153.08 seconds
# Starting batch of 638 images from index 256000
# Batch completed in 104.06 seconds
# CPU times: user 22min 43s, sys: 16min 55s, total: 39min 38s
# Wall time: 10h 56min 31s

# %%
query = face_recognition.load_image_file('osma-kuva.jpg')
locations = face_recognition.face_locations(query)
print(locations)
face_encoding = face_recognition.face_encodings(query)[0]
print(face_encoding)
# Out:
# [(82, 225, 211, 96)]
# [-0.112992   -0.01856994 -0.0725853  -0.09649391 -0.16523461 -0.07953854
#  -0.00780557 -0.05252969  0.1658026  -0.04653539  0.21516499 -0.00837498
#  -0.21343192 -0.07469685  0.02241262  0.03791903 -0.23449044 -0.0604848
#  -0.03576201 -0.07497106  0.05139757  0.08219927  0.05865814  0.10649666
#  -0.07659778 -0.24931926 -0.18466085 -0.14079696  0.11696776 -0.14492443
#   0.06956836  0.04394766 -0.12295131 -0.07461664  0.03020756  0.01194246
#  -0.05413097 -0.14314765  0.20410654 -0.04227009 -0.13628951 -0.09877791
#   0.04835489  0.2705321   0.17048754 -0.02328808 -0.00470283  0.00742704
#   0.10339205 -0.24527058  0.10911448  0.09507908  0.1628359   0.00407935
#   0.08549176 -0.08851896  0.01210636  0.24765711 -0.20378277  0.14176355
#   0.03077297 -0.11151616 -0.05128714 -0.04091938  0.18774602  0.12404893
#  -0.09956311 -0.19925664  0.18692112 -0.20792027 -0.15209027  0.18592787
#  -0.09615736 -0.18231547 -0.22061628 -0.03854696  0.42444381  0.09479684
#  -0.1213178   0.03775262 -0.07231986 -0.0883434   0.00569776  0.07984543
#  -0.07760237 -0.04787572 -0.13585126  0.04153462  0.23680472 -0.01949451
#  -0.07219561  0.26104271  0.03278638  0.01223157  0.07442504  0.00579868
#   0.06004738 -0.03272276 -0.02055301  0.01118029  0.11960458 -0.19145776
#  -0.07601519  0.07838485 -0.18907923  0.17670472  0.03598645 -0.01175598
#   0.00350394 -0.09147647 -0.09031608  0.06104103  0.22943501 -0.35513523
#   0.2018488   0.1399696   0.08859595  0.16598426 -0.08745972  0.03597617
#   0.01228353 -0.14945787 -0.18342866 -0.07361505  0.02699005 -0.06674488
#   0.02838131  0.05082276]

# %%
# %%time

encodings = numpy.array([face[2] for face in faces2])
distances = face_recognition.face_distance(encodings, face_encoding)
ranking = distances.argsort()[:10]
print(ranking)
print(distances[ranking])
for idx in ranking:
    print(faces2[idx][0], faces2[idx][1])
# Out:
# [10218   472  3159 11971  4706 11517  2478  3244 10645  9490]
# [0.57957923 0.58041262 0.58547511 0.59846391 0.60128366 0.60553537
#  0.60595661 0.60844668 0.60984907 0.61123429]
# musketti.M012:HK19651016:1436 (142, 379, 409, 111)
# musketti.M012:HK19670603:2116 (122, 73, 158, 37)
# lusto.M011-11266 (106, 185, 196, 96)
# muistaja_kerava.M011-95357 (170, 246, 232, 183)
# musketti.M012:HK6001:60022 (171, 468, 439, 200)
# musketti.M012:HK19321130:1586-1878 (211, 268, 340, 139)
# ksm.urn:nbn:fi-ksmuseohttp%3A%2F%2Fwww.profium.com%2Farchive%2FArchivedObject-9D6F0AE6-AB49-6F18-5ED8-3508536AF8DA (219, 442, 374, 287)
# muistaja_nurmijarvi.M011-95505 (128, 235, 235, 127)
# ksm.urn:nbn:fi-ksmuseohttp%3A%2F%2Fwww.profium.com%2Farchive%2FArchivedObject-E27A5F34-E87E-7030-5C94-3C5ABF3E7082 (201, 448, 387, 262)
# musketti.M012:HK19321130:440-1877 (182, 268, 311, 139)
# CPU times: user 20 ms, sys: 0 ns, total: 20 ms
# Wall time: 18.5 ms
